# %%
import pandas as pd

# %%
weather_16_17 = pd.read_csv("data_weather/weather_16_17.csv")
weather_18_19 = pd.read_csv("data_weather/weather_18_19.csv")
weather_22_23 = pd.read_csv("data_weather/weather_22_23.csv")
weather_24_25 = pd.read_csv("data_weather/weather_24_25.csv")

# %%
len(weather_16_17.columns),len(weather_18_19.columns),len(weather_22_23.columns),len(weather_24_25.columns)
# Out:
# (33, 33, 33, 33)

# %%
correct,wrong=0,0
for i in range(len(weather_16_17.columns)):
    if list(weather_16_17.columns)[i]==list(weather_18_19.columns)[i]:
        if list(weather_18_19.columns)[i]==list(weather_22_23.columns)[i]:
            if list(weather_22_23.columns)[i]==list(weather_24_25.columns)[i]:
                correct+=1
                if(i==1):
                    print(list(weather_16_17.columns)[i],list(weather_18_19.columns)[i],list(weather_22_23.columns)[i],list(weather_24_25.columns)[i])
    else:
        wrong+=1
# Out:
# datetime datetime datetime datetime

# %%
weather_all = pd.concat(
    [weather_16_17, weather_18_19, weather_22_23, weather_24_25],
    ignore_index=True
)

# %%
len(weather_all)
# Out:
# 2922

# %%
365*8+2
# Out:
# 2922

# %%
weather_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2922 non-null   object
#  1   datetime          2922 non-null   object
#  2   tempmax           2922 non-null   float64
#  3   tempmin           2922 non-null   float64
#  4   temp              2922 non-null   float64
#  5   feelslikemax      2922 non-null   float64
#  6   feelslikemin      2922 non-null   float64
#  7   feelslike         2922 non-null   float64
#  8   dew               2922 non-null   float64
#  9   humidity          2922 non-null   float64
#  10  precip            2922 non-null   float64
#  11  precipprob        2922 non-null   int64
#  12  precipcover       2922 non-null   float64
#  13  preciptype        1740 non-null   object
#  14  snow              2922 non-null   int64
#  15  snowdepth         2922 non-null   int64
# ...

# %%
weather_all.head(2)
# Out:
#                      name    datetime  tempmax  tempmin  temp  feelslikemax  \
# 0  12.9135218, 77.5950804  2016-01-01     28.1     16.1  21.1          27.4
# 1  12.9135218, 77.5950804  2016-01-02     28.1     14.1  21.4          27.0
#
#    feelslikemin  feelslike   dew  humidity  ...  solarenergy  uvindex  \
# 0          16.1       21.0  13.9      67.7  ...         20.7        8
# 1          14.1       21.2  10.4      54.1  ...         21.7        9
#
#    severerisk              sunrise               sunset  moonphase  \
# 0         NaN  2016-01-01T06:41:30  2016-01-01T18:04:12       0.72
# 1         NaN  2016-01-02T06:41:53  2016-01-02T18:04:46       0.75
#
#          conditions                           description               icon  \
# 0  Partially cloudy     Partly cloudy throughout the day.  partly-cloudy-day
# 1             Clear  Clear conditions throughout the day.          clear-day
#
#                                             stations
# ...

# %%
weather_all.tail(2)
# Out:
#                         name    datetime  tempmax  tempmin  temp  \
# 2920  12.9135218, 77.5950804  2025-12-30     27.9     18.0  22.3
# 2921  12.9135218, 77.5950804  2025-12-31     28.9     17.0  22.6
#
#       feelslikemax  feelslikemin  feelslike   dew  humidity  ...  solarenergy  \
# 2920          28.0          18.0       22.3  16.0      70.1  ...         20.7
# 2921          29.3          17.0       22.8  17.4      74.8  ...         17.9
#
#       uvindex  severerisk              sunrise               sunset  \
# 2920        8        10.0  2025-12-30T06:40:59  2025-12-30T18:03:27
# 2921        8        10.0  2025-12-31T06:41:23  2025-12-31T18:04:01
#
#       moonphase        conditions                        description  \
# 2920       0.36  Partially cloudy  Partly cloudy throughout the day.
# 2921       0.39  Partially cloudy  Partly cloudy throughout the day.
#
#                    icon   stations
# 2920  partly-cloudy-day  VOBG,VOBL
# 2921  partly-cloudy-day  VOBG,VOBL
#
# ...

# %%
weather_all["date"] = pd.to_datetime(weather_all["datetime"])

# %%
weather_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2922 non-null   object
#  1   datetime          2922 non-null   object
#  2   tempmax           2922 non-null   float64
#  3   tempmin           2922 non-null   float64
#  4   temp              2922 non-null   float64
#  5   feelslikemax      2922 non-null   float64
#  6   feelslikemin      2922 non-null   float64
#  7   feelslike         2922 non-null   float64
#  8   dew               2922 non-null   float64
#  9   humidity          2922 non-null   float64
#  10  precip            2922 non-null   float64
#  11  precipprob        2922 non-null   int64
#  12  precipcover       2922 non-null   float64
#  13  preciptype        1740 non-null   object
#  14  snow              2922 non-null   int64
#  15  snowdepth         2922 non-null   int64
# ...

# %%
df=weather_all

# %%
len(df['conditions'].unique())
df['conditions'].unique()
# Out:
# array(['Partially cloudy', 'Clear', 'Rain, Partially cloudy',
#        'Rain, Overcast', 'Rain'], dtype=object)

# %%
weather_all['sunrise'] = pd.to_datetime(weather_all['sunrise'])
weather_all['sunset'] = pd.to_datetime(weather_all['sunset'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2922 non-null   object
#  1   datetime          2922 non-null   object
#  2   tempmax           2922 non-null   float64
#  3   tempmin           2922 non-null   float64
#  4   temp              2922 non-null   float64
#  5   feelslikemax      2922 non-null   float64
#  6   feelslikemin      2922 non-null   float64
#  7   feelslike         2922 non-null   float64
#  8   dew               2922 non-null   float64
#  9   humidity          2922 non-null   float64
#  10  precip            2922 non-null   float64
#  11  precipprob        2922 non-null   int64
#  12  precipcover       2922 non-null   float64
#  13  preciptype        1740 non-null   object
#  14  snow              2922 non-null   int64
#  15  snowdepth         2922 non-null   int64
# ...

# %%
len(df)
# Out:
# 2922

# %%
df.isna().sum()
# Out:
# name                   0
# datetime               0
# tempmax                0
# tempmin                0
# temp                   0
# feelslikemax           0
# feelslikemin           0
# feelslike              0
# dew                    0
# humidity               0
# precip                 0
# precipprob             0
# precipcover            0
# preciptype          1182
# snow                   0
# snowdepth              0
# windgust               0
# windspeed              0
# winddir                0
# sealevelpressure       0
# cloudcover             0
# visibility             0
# solarradiation         0
# solarenergy            0
# uvindex                0
# severerisk          1470
# sunrise                0
# sunset                 0
# moonphase              0
# conditions             0
# description            0
# icon                   0
# stations               0
# date                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 34 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              2922 non-null   object
#  1   datetime          2922 non-null   object
#  2   tempmax           2922 non-null   float64
#  3   tempmin           2922 non-null   float64
#  4   temp              2922 non-null   float64
#  5   feelslikemax      2922 non-null   float64
#  6   feelslikemin      2922 non-null   float64
#  7   feelslike         2922 non-null   float64
#  8   dew               2922 non-null   float64
#  9   humidity          2922 non-null   float64
#  10  precip            2922 non-null   float64
#  11  precipprob        2922 non-null   int64
#  12  precipcover       2922 non-null   float64
#  13  preciptype        1740 non-null   object
#  14  snow              2922 non-null   int64
#  15  snowdepth         2922 non-null   int64
# ...

# %%
cols=['precipprob','snow','snowdepth']
for i in cols:
    print(df[i].value_counts())
    print('\n')
# Out:
# precipprob
# 100    1662
# 0      1260
# Name: count, dtype: int64
#
#
# snow
# 0    2922
# Name: count, dtype: int64
#
#
# snowdepth
# 0    2922
# Name: count, dtype: int64

# %%
df.drop(['name','datetime','feelslikemax','feelslikemin','feelslike','precipprob','snow','snowdepth','stations'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   tempmax           2922 non-null   float64
#  1   tempmin           2922 non-null   float64
#  2   temp              2922 non-null   float64
#  3   dew               2922 non-null   float64
#  4   humidity          2922 non-null   float64
#  5   precip            2922 non-null   float64
#  6   precipcover       2922 non-null   float64
#  7   preciptype        1740 non-null   object
#  8   windgust          2922 non-null   float64
#  9   windspeed         2922 non-null   float64
#  10  winddir           2922 non-null   float64
#  11  sealevelpressure  2922 non-null   float64
#  12  cloudcover        2922 non-null   float64
#  13  visibility        2922 non-null   float64
#  14  solarradiation    2922 non-null   float64
#  15  solarenergy       2922 non-null   float64
# ...

# %%
df.isna().sum()
# Out:
# tempmax                0
# tempmin                0
# temp                   0
# dew                    0
# humidity               0
# precip                 0
# precipcover            0
# preciptype          1182
# windgust               0
# windspeed              0
# winddir                0
# sealevelpressure       0
# cloudcover             0
# visibility             0
# solarradiation         0
# solarenergy            0
# uvindex                0
# severerisk          1470
# sunrise                0
# sunset                 0
# moonphase              0
# conditions             0
# description            0
# icon                   0
# date                   0
# dtype: int64

# %%
len(df)
# Out:
# 2922

# %%
df.drop(['severerisk'],axis=1,inplace=True)

# %%
df['preciptype'].value_counts()
# Out:
# preciptype
# rain    1740
# Name: count, dtype: int64

# %%
df["preciptype"] = df["preciptype"].fillna("no rain")

# %%
df.isna().sum()
# Out:
# tempmax             0
# tempmin             0
# temp                0
# dew                 0
# humidity            0
# precip              0
# precipcover         0
# preciptype          0
# windgust            0
# windspeed           0
# winddir             0
# sealevelpressure    0
# cloudcover          0
# visibility          0
# solarradiation      0
# solarenergy         0
# uvindex             0
# sunrise             0
# sunset              0
# moonphase           0
# conditions          0
# description         0
# icon                0
# date                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['tempmax', 'tempmin', 'temp', 'dew', 'humidity', 'precip',
#        'precipcover', 'preciptype', 'windgust', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'solarradiation',
#        'solarenergy', 'uvindex', 'sunrise', 'sunset', 'moonphase',
#        'conditions', 'description', 'icon', 'date'],
#       dtype='object')

# %%
cols = ["date"] + [c for c in df.columns if c != "date"]
df = df[cols]

# %%
df.head().T
# Out:
#                                                   0  \
# date                            2016-01-01 00:00:00
# tempmax                                        28.1
# tempmin                                        16.1
# temp                                           21.1
# dew                                            13.9
# humidity                                       67.7
# precip                                          0.0
# precipcover                                     0.0
# preciptype                                  no rain
# windgust                                       41.8
# windspeed                                      27.4
# winddir                                        89.8
# sealevelpressure                             1020.9
# cloudcover                                     38.9
# visibility                                      6.0
# solarradiation                                240.5
# solarenergy                                    20.7
# ...

# %%
# df.to_csv("data_weather/weather_all_clean.csv", index=False)
