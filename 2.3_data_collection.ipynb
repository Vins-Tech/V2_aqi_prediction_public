# %%
import pandas as pd

# %%
df1=pd.read_csv('data_aqi/aqi_2016_to_2025_exclude_20_21.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2922 non-null   object
#  1   pm25    2601 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 45.8+ KB

# %%
df2=pd.read_csv('data_weather/weather_all_clean.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2922 non-null   object
#  1   tempmax           2922 non-null   float64
#  2   tempmin           2922 non-null   float64
#  3   temp              2922 non-null   float64
#  4   dew               2922 non-null   float64
#  5   humidity          2922 non-null   float64
#  6   precip            2922 non-null   float64
#  7   precipcover       2922 non-null   float64
#  8   preciptype        2922 non-null   object
#  9   windgust          2922 non-null   float64
#  10  windspeed         2922 non-null   float64
#  11  winddir           2922 non-null   float64
#  12  sealevelpressure  2922 non-null   float64
#  13  cloudcover        2922 non-null   float64
#  14  visibility        2922 non-null   float64
#  15  solarradiation    2922 non-null   float64
# ...

# %%
len(df1),len(df2)
# Out:
# (2922, 2922)

# %%
correct,wrong=0,0
for i in range(len(df1)):
    if(df1.iloc[i]['date']==df2.iloc[i]['date']):
        correct+=1
    else:
        wrong+=1

# %%
correct,wrong
# Out:
# (2922, 0)

# %%
df2['pm25']=df1['pm25']

# %%
df2.head().T
# Out:
#                                                   0  \
# date                                     2016-01-01
# tempmax                                        28.1
# tempmin                                        16.1
# temp                                           21.1
# dew                                            13.9
# humidity                                       67.7
# precip                                          0.0
# precipcover                                     0.0
# preciptype                                  no rain
# windgust                                       41.8
# windspeed                                      27.4
# winddir                                        89.8
# sealevelpressure                             1020.9
# cloudcover                                     38.9
# visibility                                      6.0
# solarradiation                                240.5
# solarenergy                                    20.7
# ...

# %%
df2.to_csv("data/data1.csv", index=False)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2922 entries, 0 to 2921
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              2922 non-null   object
#  1   tempmax           2922 non-null   float64
#  2   tempmin           2922 non-null   float64
#  3   temp              2922 non-null   float64
#  4   dew               2922 non-null   float64
#  5   humidity          2922 non-null   float64
#  6   precip            2922 non-null   float64
#  7   precipcover       2922 non-null   float64
#  8   preciptype        2922 non-null   object
#  9   windgust          2922 non-null   float64
#  10  windspeed         2922 non-null   float64
#  11  winddir           2922 non-null   float64
#  12  sealevelpressure  2922 non-null   float64
#  13  cloudcover        2922 non-null   float64
#  14  visibility        2922 non-null   float64
#  15  solarradiation    2922 non-null   float64
# ...
