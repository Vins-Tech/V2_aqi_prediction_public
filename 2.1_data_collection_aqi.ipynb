# %%
import pandas as pd

# %%
df=pd.read_csv('data_aqi/aqi.csv')

# %%
len(df)
# Out:
# 3900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3900 non-null   object
#  1    pm25   3900 non-null   object
#  2    pm10   3900 non-null   object
#  3    o3     3900 non-null   object
#  4    no2    3900 non-null   object
#  5    so2    3900 non-null   object
#  6    co     3900 non-null   object
# dtypes: object(7)
# memory usage: 213.4+ KB

# %%
df.columns
# Out:
# Index(['date', ' pm25', ' pm10', ' o3', ' no2', ' so2', ' co'], dtype='object')

# %%
df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['date', 'pm25', 'pm10', 'o3', 'no2', 'so2', 'co'], dtype='object')

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3900 non-null   datetime64[ns]
#  1   pm25    3900 non-null   object
#  2   pm10    3900 non-null   object
#  3   o3      3900 non-null   object
#  4   no2     3900 non-null   object
#  5   so2     3900 non-null   object
#  6   co      3900 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 213.4+ KB

# %%
lst=list(df['pm25'].unique())
a=[]
b=[]
for i in lst:
    if i.strip().isdigit():
        a.append(i)
    else:
        b.append(i)

# %%
df['pm25'].value_counts()[' ']
# Out:
# np.int64(392)

# %%
pollutant_cols = ['pm25', 'pm10', 'o3', 'no2', 'so2', 'co']

for col in pollutant_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3900 non-null   datetime64[ns]
#  1   pm25    3508 non-null   float64
#  2   pm10    1662 non-null   float64
#  3   o3      3288 non-null   float64
#  4   no2     3637 non-null   float64
#  5   so2     3236 non-null   float64
#  6   co      3722 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 213.4 KB

# %%
len(df)
# Out:
# 3900

# %%
df.isna().sum()
# Out:
# date       0
# pm25     392
# pm10    2238
# o3       612
# no2      263
# so2      664
# co       178
# dtype: int64

# %%
df = df.sort_values('date')

# %%
df.head()
# Out:
#            date  pm25  pm10  o3   no2  so2    co
# 3885 2013-12-31   NaN   NaN NaN   NaN  3.0   4.0
# 3832 2014-01-01   NaN   NaN NaN   9.0  2.0   2.0
# 3833 2014-01-02   NaN   NaN NaN   6.0  2.0  11.0
# 3834 2014-01-03   NaN   NaN NaN  12.0  3.0   5.0
# 3835 2014-01-04   NaN   NaN NaN   6.0  2.0   9.0

# %%
df.tail()
# Out:
#         date   pm25  pm10   o3  no2  so2   co
# 0 2026-01-01  151.0  80.0  7.0  7.0  5.0  NaN
# 1 2026-01-02  141.0  80.0  7.0  7.0  5.0  1.0
# 2 2026-01-03  146.0  80.0  7.0  8.0  5.0  1.0
# 3 2026-01-04  144.0  80.0  7.0  8.0  5.0  1.0
# 4 2026-01-05  144.0   NaN  NaN  NaN  NaN  NaN

# %%
365*12+5+1+3
# Out:
# 4389

# %%
len(df)
# Out:
# 3900

# %%
df['date'].dt.year.value_counts().sort_index()
# Out:
# date
# 2013      1
# 2014    140
# 2015    322
# 2016    346
# 2017    329
# 2018    339
# 2019    353
# 2020    362
# 2021    340
# 2022    350
# 2023    358
# 2024    327
# 2025    328
# 2026      5
# Name: count, dtype: int64

# %%
df = df[['date', 'pm25']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3900 entries, 3885 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3900 non-null   datetime64[ns]
#  1   pm25    3508 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 91.4 KB

# %%
df_filtered = df[
    (df["date"] >= "2014-01-01") &
    (df["date"] <= "2025-12-31")
]

df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3894 entries, 3832 to 3508
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3894 non-null   datetime64[ns]
#  1   pm25    3503 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 91.3 KB

# %%
len(df_filtered
    )
# Out:
# 3894

# %%
df=df_filtered

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3894 entries, 3832 to 3508
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3894 non-null   datetime64[ns]
#  1   pm25    3503 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 91.3 KB

# %%
for i in range(2014,2026):
    print(i,df[df['date'].dt.year==i].isna().sum()['pm25'],len(df[df['date'].dt.year==i]))
# Out:
# 2014 140 140
# 2015 103 322
# 2016 41 346
# 2017 12 329
# 2018 12 339
# 2019 5 353
# 2020 6 362
# 2021 13 340
# 2022 9 350
# 2023 13 358
# 2024 27 327
# 2025 10 328

# %%
values_check1=df['date'].dt.year.value_counts().sort_index()
values_check1
# Out:
# date
# 2014    140
# 2015    322
# 2016    346
# 2017    329
# 2018    339
# 2019    353
# 2020    362
# 2021    340
# 2022    350
# 2023    358
# 2024    327
# 2025    328
# Name: count, dtype: int64

# %%
full_dates = pd.date_range(
    start=df['date'].min(),
    end=df['date'].max(),
    freq='D'
)

df = df.set_index('date').reindex(full_dates).rename_axis('date').reset_index()

# %%
df['date'].dt.year.value_counts().sort_index()
# Out:
# date
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025    365
# Name: count, dtype: int64

# %%
values_check1
# Out:
# date
# 2014    140
# 2015    322
# 2016    346
# 2017    329
# 2018    339
# 2019    353
# 2020    362
# 2021    340
# 2022    350
# 2023    358
# 2024    327
# 2025    328
# Name: count, dtype: int64

# %%
df[df['date'].dt.year==2014].isna().sum()
# Out:
# date      0
# pm25    365
# dtype: int64

# %%
for i in range(2014,2026):
    print(i,df[df['date'].dt.year==i].isna().sum()['pm25'])
# Out:
# 2014 365
# 2015 146
# 2016 61
# 2017 48
# 2018 38
# 2019 17
# 2020 10
# 2021 38
# 2022 24
# 2023 20
# 2024 66
# 2025 47

# %%
len(df)-365*2
# Out:
# 3653

# %%
df = df[(df['date'].dt.year >= 2016) & (df['date'].dt.year <= 2025)]

# %%
len(df)
# Out:
# 3653

# %%
df["date"].dt.year.min(), df["date"].dt.year.max()
# Out:
# (np.int32(2016), np.int32(2025))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 5))
plt.plot(df["date"], df["pm25"])
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Daily PM2.5 Levels (2016–2025)")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Monthly average (as you already did)
monthly_avg = (
    df.groupby(df["date"].dt.to_period("M"))["pm25"]
      .mean()
)

monthly_avg.index = monthly_avg.index.to_timestamp()

plt.figure(figsize=(14, 5))
plt.plot(monthly_avg.index, monthly_avg.values)

# Add vertical lines at each year boundary
for year in range(2016, 2026):
    plt.axvline(
        x=pd.Timestamp(f"{year}-01-01"),
        linestyle="--",
        linewidth=0.8,
        alpha=0.6
    )

# Format x-axis to show years clearly
plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y"))

plt.xlabel("Year")
plt.ylabel("Average PM2.5")
plt.title("Monthly Average PM2.5 with Year Separators (2016–2025)")
plt.tight_layout()
plt.show()

# %%
yearly_avg = df.groupby(df["date"].dt.year)["pm25"].mean()

plt.figure(figsize=(10, 5))
plt.plot(yearly_avg.index, yearly_avg.values, marker="o")

plt.xticks(yearly_avg.index)   # 👈 force all years

plt.xlabel("Year")
plt.ylabel("Average PM2.5")
plt.title("Yearly Average PM2.5 (2016–2025)")
plt.tight_layout()
plt.show()

# %%
# df.to_csv("data_aqi/aqi_2016_to_2025.csv", index=False)

# %%
df_no_covid = df[~df["date"].dt.year.isin([2020, 2021])]

# %%
df_no_covid["date"].dt.year.value_counts().sort_index()
# Out:
# date
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2022    365
# 2023    365
# 2024    366
# 2025    365
# Name: count, dtype: int64

# %%
# df_no_covid.to_csv("data_aqi/aqi_2016_to_2025_exclude_20_21.csv", index=False)
